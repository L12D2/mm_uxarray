# %%
import xarray as xr
import numpy as np

O = "/glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test"

# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_co_cam-chem-se_obsgrid.nc4
# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_co_cam-chem-se.nc4
# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_hcho_cam-chem-se_obsgrid.nc4
# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_hcho_cam-chem-se.nc4
# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_no2_cam-chem-se_obsgrid.nc4
# u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/hcho_ben_gaubert_cs/test/test_tropomi_l2_no2_cam-chem-se.nc4

files = [
    "test_tropomi_l2_co_cam-chem-se_obsgrid.nc4",
    "test_tropomi_l2_co_cam-chem-se.nc4",
    "test_tropomi_l2_hcho_cam-chem-se_obsgrid.nc4",
    "test_tropomi_l2_hcho_cam-chem-se.nc4",
    "test_tropomi_l2_no2_cam-chem-se_obsgrid.nc4",
    "test_tropomi_l2_no2_cam-chem-se.nc4",
]

for fname in files:
    ds = xr.open_dataset(f"{O}/{fname}")

    print(f"\n{fname}")

    for var in ds.data_vars:
        if np.issubdtype(ds[var].dtype, np.number):
            mean_val = float(ds[var].mean(skipna=True))

            print(f"  {var:50s} {mean_val:.6e}")

    ds.close()
    
# # paired TROPOMI obs (should be ~1e15-1e16 if converted)
# d = xr.open_dataset(f"{O}/20240315_tropomi_l2_hcho_cam-chem-se.nc4")
# print("TROPOMI paired obs mean:", float(np.nanmean(d["formaldehyde_tropospheric_vertical_column"])))
# print("TROPOMI paired model mean:", float(np.nanmean(d["CH2O"])))

# # raw granule value + its units, to compare
# g = xr.open_dataset(sorted(__import__("glob").glob(
#     "/glade/campaign/acom/acom-da/sma/TROPOMI-HCHO-DATA/2024/S5P_OFFL_L2__HCHO___20240415T032224_20240415T050355_33706_03_020601_20240418T100607.nc"))[0], group="PRODUCT")
# vc = g["formaldehyde_tropospheric_vertical_column"]
# print("raw units:", vc.attrs.get("units"), "raw mean:", float(np.nanmean(vc)))

# # TEMPO for reference
# t = xr.open_dataset(f"{O}/20240315_tempo_l2_hcho_cam-chem-se.nc4")
# print("TEMPO paired obs mean:", float(np.nanmean(t["vertical_column"])))
# Out:
# test_tropomi_l2_co_cam-chem-se_obsgrid.nc4
#   CO                                                 1.008354e+18
#   carbonmonoxide_total_column                        1.751604e+18
#
# test_tropomi_l2_co_cam-chem-se.nc4
#   CO                                                 1.095502e+18
#   carbonmonoxide_total_column                        1.818083e+18
#
# test_tropomi_l2_hcho_cam-chem-se_obsgrid.nc4
#   CH2O                                               2.861921e+15
#   formaldehyde_tropospheric_vertical_column          5.458268e+15
#
# test_tropomi_l2_hcho_cam-chem-se.nc4
#   CH2O                                               2.935267e+15
#   formaldehyde_tropospheric_vertical_column          5.213169e+15
#
# test_tropomi_l2_no2_cam-chem-se_obsgrid.nc4
#   NO2                                                2.714285e+14
#   nitrogendioxide_tropospheric_column                8.063338e+14
#
# test_tropomi_l2_no2_cam-chem-se.nc4
# ...
