# %% [markdown]
# # ASIA AQ CS
#
# #### Liam Thompson, Jun Zhang

# %%
from melodies_monet import driver

# %%
an = driver.analysis()
an

an.control = '/glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/readthedocs/control_1x_track_cesm_se_asia_aq.yaml'

an.read_control()

an.open_models()
an.open_obs()

an.pair_data()

an.save_analysis()

an.read_analysis()
an.plotting()
an.stats()
# Out:
# Scrip file /glade/work/emmons/VRM_Files/ne0np4.GEMS01.ne30x8/grids/GEMS01_ne30x8_np4_SCRIP.nc
# ['/glade/derecho/scratch/jzhan166/f.e30beta01.FCnudged.GEMS01ne30x8.XNOx_PHL_anthro.02/run/f.e30beta01.FCnudged.GEMS01ne30x8.XNOx_PHL_anthro.02.cam.aircraft_asiaaqdc8_1s_1pt.2024-02-13-06525.nc']
# 1, in pair data
# WARNING: max obs-model time gap = 1126.7 h -- wrong obs file for this model day?
# [track] paired dc8_cam-chem-se-era5: 8214 points
# Writing: ./output/1x_asia_aq_cesmse/0213_jz_asiaaq_dc8_cam-chem-se-era5.nc4
# Reading: /glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/jun_zhang_cs_06122026/output_021324/0213_jz_asiaaq_dc8_cam-chem-se-era5.nc4
# Using vertprofile_bins from YAML range: {'start': 10000, 'stop': 110000, 'step': 5000}
# Using vertprofile_bins from YAML range: {'start': 10000, 'stop': 110000, 'step': 5000}
# Using vertprofile_bins from YAML range: {'start': 10000, 'stop': 110000, 'step': 5000}
# ...
