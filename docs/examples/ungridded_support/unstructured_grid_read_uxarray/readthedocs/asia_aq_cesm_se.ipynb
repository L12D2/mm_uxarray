# %% [markdown]
# # ASIA AQ CS
#
# #### Liam Thompson, Jun Zhang

# %%
from melodies_monet import driver

# %%
an = driver.analysis()
an

an.control = '/glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/readthedocs/control_asia_aq_cesm_se.yaml'

an.read_control()

an.open_models()
an.open_obs()

an.pair_data()

#an.save_analysis()

an.read_analysis()
an.plotting()
# Out:
# Scrip file /glade/campaign/acom/MUSICA/grids/GEMSne30x8/GEMS01_ne30x8_np4_SCRIP.nc
# cesm_se
# ['/glade/campaign/acom/acom-weather/emmons/ASIAAQ_sims/f.e3b08.FHISTC_LTt1s.camsm11_finn27.era5.GEMSne30x8.2024.01/atm/hist/f.e3b08.FHISTC_LTt1s.camsm11_finn27.era5.GEMSne30x8.2024.01.cam.h5a.2024-03-27-03600.nc']
# **** Reading CAM unstructured model output (cesm_se / mpas)...
# Using unstructured grid file: /glade/campaign/acom/MUSICA/grids/GEMSne30x8/GEMS01_ne30x8_np4_SCRIP.nc
# Opening unstructured grid with UXArray: /glade/campaign/acom/MUSICA/grids/GEMSne30x8/GEMS01_ne30x8_np4_SCRIP.nc
# unstructured reader: requested vars not in '/glade/campaign/acom/acom-weather/emmons/ASIAAQ_sims/f.e3b08.FHISTC_LTt1s.camsm11_finn27.era5.GEMSne30x8.2024.01/atm/hist/f.e3b08.FHISTC_LTt1s.camsm11_finn27.era5.GEMSne30x8.2024.01.cam.h5a.2024-03-27-03600.nc': ['P0']. Continuing with: ['CO', 'T', 'NO2', 'O3', 'lat', 'lon', 'lev', 'hyam', 'hybm', 'PS', 'PDELDRY', 'PMID'].
# ...
