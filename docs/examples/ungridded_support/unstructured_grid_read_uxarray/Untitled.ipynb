# %%
# 2. Reader output — pass a STRING (single path), not a list
import monetio as mio
F = "/glade/campaign/acom/acom-weather/amirrezaei/tropomi_no2/2024/S5P_OFFL_L2__NO2____20240101T074458_20240101T092629_32219_03_020600_20240102T234600.nc"
ds = mio.sat.tropomi_l2_no2.open_dataset(F, {"nitrogendioxide_tropospheric_column": {}})
g = ds[list(ds)[0]] if isinstance(ds, dict) else ds
print("type:", type(ds).__name__)
print("dims:", dict(g.sizes))
print("vars:", list(g.variables))
print("has bounds:", [v for v in g.variables if "bound" in v.lower()])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 2. Reader output — pass a STRING (single path), not a list
# ----> 2 import monetio as mio
#       3 F = "/glade/campaign/acom/acom-weather/amirrezaei/tropomi_no2/2024/S5P_OFFL_L2__NO2____20240101T074458_20240101T092629_32219_03_020600_20240102T234600.nc"
#       4 ds = mio.sat.tropomi_l2_no2.open_dataset(F, {"nitrogendioxide_tropospheric_column": {}})
#
# ModuleNotFoundError: No module named 'monetio'
