# %% [markdown]
# # ASIA AQ CS
#
# #### Liam Thompson, Benjamin Gaubert, Louisa Emmons

# %%
from melodies_monet import driver

# %%
# Needed if you want to make changes to `melodies_monet` and don't want to restart kernel:
# %load_ext autoreload

# %autoreload 2

# %%
an = driver.analysis()
an

an.control = '/glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/asiaaq_cs_06082026/output/dc8_yaml/control_dc8_20240202.yaml'

an.read_control()
#an.control_dict

# %%
an.open_models()
# an.models

# %%
# print(an.models['cam-chem-se-merra2'].label)
# print(an.models['cam-chem-se-merra2'].mapping)

# print(an.models['cam-chem-se-era5'].label)
# print(an.models['cam-chem-se-era5'].mapping)

# %%
an.control_dict['obs']
an.open_obs()

# %%
# m = an.models['cam-chem-se-merra2'].obj
# print([v for v in m.variables if 'pres' in v.lower()])      # pres_pa_mid? pres_pa_int?
# print([v for v in m.variables if v in ('PS','hyam','hybm','P0','dz_m','temperature_k')])
# print(dict(m['z'].attrs) if 'z' in m.coords else "no z coord attrs")

# %%
#an.pair_data()

#an.paired
an.read_analysis()

# %%
# %%time

an.plotting()

# %%
an.stats()
