# %% [markdown]
# # MONET-analysis dev
#
# First lets just import the driver to see how it happens and so we can play around with it a little

# %%
import driver
# Out:
# /scratch2/BMC/rcm1/rhs/anaconda3/envs/py36_monet_default/lib/python3.6/site-packages/pyresample/bilinear/__init__.py:49: UserWarning: XArray and/or zarr not found, XArrayBilinearResampler won't be available.
#   warnings.warn("XArray and/or zarr not found, XArrayBilinearResampler won't be available.")
# Please install h5py to open files from the Amazon S3 servers.
# Please install h5netcdf to open files from the Amazon S3 servers.

# %% [markdown]
# ### Driver class
#
# Now lets create an instance of the python driver analysis class. It consists of 4 main parts; model instances, observation instances, a paired instance of both.  This will allow us to move things around the plotting function for spatial and overlays and more complex plots.

# %%
an = driver.analysis()

# %% [markdown]
# If needed link files into one common directory to look at multiple days.

# %% [markdown]
# ### Control File
#
# set the yaml control file and begin by reading the file

# %%
an.control = 'control_cmaq-rrfs_surface-all-short_test_jupyter.yaml'
an.read_control() # control='control.yaml')
an.control_dict
# Out:
# {'analysis': {'start_time': '2019-08-01-12:00:00',
#   'end_time': '2019-08-02-12:00:00',
#   'output_dir': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08_test/',
#   'debug': True},
#  'model': {'rrfs_r131v1': {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/rrfs/*0801*dynf*.nc',
#    'files_pm25': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/rrfs/*0801*pm25tot_f*.nc',
#    'mod_type': 'rrfs',
#    'mod_kwargs': {'mech': 'cb6r3_ae6_aq', 'surf_only': True},
#    'radius_of_influence': 19500,
#    'mapping': {'airnow': {'co': 'CO',
#      'no2': 'NO2',
#      'no': 'NO',
#      'PM25_TOT': 'PM2.5',
#      'o3': 'OZONE'}},
#    'projection': 'None',
#    'plot_kwargs': {'color': 'dodgerblue', 'marker': 'D', 'linestyle': '-'}},
#   'cmaq_oper': {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_oper/*0801*',
#    'mod_type': 'cmaq',
#    'mod_kwargs': {'concatenate_forecasts': True},
#    'radius_of_influence': 18000,
#    'mapping': {'airnow': {'CO': 'CO',
#      'NO2': 'NO2',
#      'NO': 'NO',
#      'PM25_TOT': 'PM2.5',
#      'O3': 'OZONE'}},
#    'projection': 'None',
#    'plot_kwargs': {'color': 'goldenrod', 'marker': 's', 'linestyle': '-'}},
#   'cmaq_expt': {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_expt/*0801*',
#    'mod_type': 'cmaq',
#    'mod_kwargs': {'concatenate_forecasts': True},
#    'radius_of_influence': 18000,
#    'mapping': {'airnow': {'CO': 'CO',
#      'NO2': 'NO2',
#      'NO': 'NO',
#      'PM25_TOT': 'PM2.5',
#      'O3': 'OZONE'}},
#    'projection': 'None',
#    'plot_kwargs': {'color': 'magenta', 'marker': 'o', 'linestyle': '-'}}},
#  'obs': {'airnow': {'use_airnow': True,
#    'filename': 'data/AIRNOW_20190831_20190831.nc',
#    'obs_type': 'pt_sfc',
#    'variables': {'PM2.5': {'unit_scale': 1,
#      'unit_scale_method': '*',
#      'nan_value': -1.0,
#      'ylabel_plot': 'PM2.5 (ug/m3)',
#      'ty_scale': 2.0,
#      'vmin_plot': 0.0,
#      'vmax_plot': 22.0,
#      'vdiff_plot': 15.0,
#      'nlevels_plot': 23},
#     'OZONE': {'unit_scale': 1,
#      'unit_scale_method': '*',
#      'nan_value': -1.0,
#      'ylabel_plot': 'Ozone (ppbv)',
#      'vmin_plot': 15.0,
#      'vmax_plot': 55.0,
#      'vdiff_plot': 20.0,
#      'nlevels_plot': 21},
#     'WS': {'unit_scale': 0.514, 'unit_scale_method': '*', 'obs_min': 0.2},
#     'PRSFC': {'unit_scale': 0.01, 'unit_scale_method': '*'},
#     'PRECIP': {'unit_scale': 0.1, 'unit_scale_method': '*'},
#     'TEMP': {'unit_scale': 273.16, 'unit_scale_method': '-'},
#     'CO': {'unit_scale': 1000.0,
#      'unit_scale_method': '*',
#      'nan_value': -1.0,
#      'ylabel_plot': 'CO (ppbv)',
#      'vmin_plot': 50.0,
#      'vmax_plot': 750.0,
#      'vdiff_plot': 400.0,
#      'nlevels_plot': 15},
#     'SO2': {'nan_value': -1.0, 'ylabel_plot': 'SO2 (ppbv)'},
#     'NO': {'nan_value': -1.0,
#      'ylabel_plot': 'NO (ppbv)',
#      'vmin_plot': 0.0,
#      'vmax_plot': 20.0,
#      'vdiff_plot': 15.0,
#      'nlevels_plot': 21},
#     'NO2': {'nan_value': -1.0,
#      'ylabel_plot': 'NO2 (ppbv)',
#      'vmin_plot': 0.0,
#      'vmax_plot': 20.0,
#      'vdiff_plot': 15.0,
#      'nlevels_plot': 21}}}},
#  'plots': {'plot_grp1': {'type': 'timeseries',
#    'fig_kwargs': {'figsize': [14, 6]},
#    'default_plot_kwargs': {'linewidth': 2.0, 'markersize': 2.0},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all', 'epa_region'],
#    'domain_name': ['CONUS', 'R1'],
#    'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper'],
#    'data_proc': {'rem_obs_nan': True,
#     'ts_select_time': 'time_local',
#     'ts_avg_window': 'H',
#     'set_axis': False}},
#   'plot_grp2': {'type': 'taylor',
#    'fig_kwargs': {'figsize': [8, 8]},
#    'default_plot_kwargs': {'markersize': 10.0},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}},
#   'plot_grp3': {'type': 'spatial_bias',
#    'fig_kwargs': {'states': True, 'figsize': [10, 5]},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}},
#   'plot_grp4': {'type': 'spatial_overlay',
#    'fig_kwargs': {'states': True, 'figsize': [10, 5]},
#    'text_kwargs': {'fontsize': 16.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': True}},
#   'plot_grp5': {'type': 'boxplot',
#    'fig_kwargs': {'figsize': [8, 6]},
#    'text_kwargs': {'fontsize': 20.0},
#    'domain_type': ['all'],
#    'domain_name': ['CONUS'],
#    'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper'],
#    'data_proc': {'rem_obs_nan': True, 'set_axis': False}}},
#  'stats': {'stat_list': ['MB', 'R2', 'RMSE'],
#   'round_output': 2,
#   'output_table': False,
#   'output_table_kwargs': {'figsize': [7, 3],
#    'fontsize': 12.0,
#    'xscale': 1.4,
#    'yscale': 1.4,
#    'edges': 'horizontal'},
#   'domain_type': ['all'],
#   'domain_name': ['CONUS'],
#   'data': ['airnow_rrfs_r131v1', 'airnow_cmaq_expt', 'airnow_cmaq_oper']}}

# %% [markdown]
# ### Loading the model data
#
# driver will automatically loop through the "models" found in the model section of the yaml file and create an instance of the driver.model class for each that includes the label, mapping information, and xarray object as well as the filenames.  Note it can open multiple files easily by including hot keys

# %%
an.open_models()
# Out:
# rrfs_r131v1
# {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/rrfs/*0801*dynf*.nc', 'files_pm25': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/rrfs/*0801*pm25tot_f*.nc', 'mod_type': 'rrfs', 'mod_kwargs': {'mech': 'cb6r3_ae6_aq', 'surf_only': True}, 'radius_of_influence': 19500, 'mapping': {'airnow': {'co': 'CO', 'no2': 'NO2', 'no': 'NO', 'PM25_TOT': 'PM2.5', 'o3': 'OZONE'}}, 'projection': 'None', 'plot_kwargs': {'color': 'dodgerblue', 'marker': 'D', 'linestyle': '-'}}
# /scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/rrfs/*0801*dynf*.nc
# [########################################] | 100% Completed |  4.5s
# [########################################] | 100% Completed |  4.6s
# [########################################] | 100% Completed |  4.6s
# [########################################] | 100% Completed |  4.7s
# [########################################] | 100% Completed |  1.0s
# [########################################] | 100% Completed |  1.1s
# [########################################] | 100% Completed |  1.2s
# [########################################] | 100% Completed |  1.1s
# [########################################] | 100% Completed |  0.8s
# [########################################] | 100% Completed |  0.9s
# [########################################] | 100% Completed |  0.9s
# [########################################] | 100% Completed |  0.9s
# [########################################] | 100% Completed |  3.6s
# [########################################] | 100% Completed |  3.6s
# [########################################] | 100% Completed |  3.7s
# [########################################] | 100% Completed |  3.7s
# cmaq_oper
# {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_oper/*0801*', 'mod_type': 'cmaq', 'mod_kwargs': {'concatenate_forecasts': True}, 'radius_of_influence': 18000, 'mapping': {'airnow': {'CO': 'CO', 'NO2': 'NO2', 'NO': 'NO', 'PM25_TOT': 'PM2.5', 'O3': 'OZONE'}}, 'projection': 'None', 'plot_kwargs': {'color': 'goldenrod', 'marker': 's', 'linestyle': '-'}}
# /scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_oper/*0801*
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# cmaq_expt
# {'files': '/scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_expt/*0801*', 'mod_type': 'cmaq', 'mod_kwargs': {'concatenate_forecasts': True}, 'radius_of_influence': 18000, 'mapping': {'airnow': {'CO': 'CO', 'NO2': 'NO2', 'NO': 'NO', 'PM25_TOT': 'PM2.5', 'O3': 'OZONE'}}, 'projection': 'None', 'plot_kwargs': {'color': 'magenta', 'marker': 'o', 'linestyle': '-'}}
# /scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08/data/cmaq_expt/*0801*
# [                                        ] | 0% Completed |  0.0s
# /scratch2/BMC/rcm1/rhs/anaconda3/envs/py36_monet_default/lib/python3.6/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# /scratch2/BMC/rcm1/rhs/anaconda3/envs/py36_monet_default/lib/python3.6/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()

# %%
#To help debug, you can print the models you incorporated
an.models
# Out:
# {'rrfs_r131v1': <driver.model at 0x7f6fef6ad3c8>,
#  'cmaq_oper': <driver.model at 0x7f70a7f58ef0>,
#  'cmaq_expt': <driver.model at 0x7f6fed9eb940>}

# %%
#Update the name to one of the model names you used and you can print the object
an.models['cmaq_expt'].obj
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 24, x: 442, y: 265, z: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 2019-08-01T13:00:00 ... 2019-08-02T12:00:00
#     longitude  (y, x) float64 -120.6 -120.5 -120.4 ... -58.98 -58.83 -58.69
#     latitude   (y, x) float64 21.89 21.92 21.95 21.97 ... 47.88 47.84 47.79
# Dimensions without coordinates: x, y, z
# Data variables: (12/21)
#     CO         (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     NO         (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     NO2        (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     NOX        (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     NOY        (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     O3         (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     ...         ...
#     PM25_SO4   (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     PM25_SOIL  (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     PM25_TOT   (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     PMC_TOT    (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     SO2        (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
#     VOC        (time, z, y, x) float32 dask.array<chunksize=(24, 1, 265, 442), meta=np.ndarray>
# Attributes: (12/35)
#     IOAPI_VERSION:  $Id: @(#) ioapi library version 3.1 $                    ...
#     EXEC_ID:        ????????????????                                         ...
#     FTYPE:          1
#     CDATE:          2019216
#     CTIME:          15159
#     WDATE:          2019216
#     ...             ...
#     UPNAM:          csum
#     VAR-LIST:       O3              CO              NO              NO2      ...
#     FILEDESC:                                                                ...
#     HISTORY:        Mon Sep 27 16:11:32 2021: ncks -d TSTEP,0,23 aqm.20190801...
#     NCO:            4.7.0
#     proj4_srs:      +proj=lcc +lat_1=33.0 +lat_2=45.0 +lat_0=40.0 +lon_0=-97....

# %%
#All the info in the analysis class can also be called.
print(an.start_time)
print(an.end_time)
print(an.output_dir)
# Out:
# 2019-08-01 12:00:00
# 2019-08-02 12:00:00
# /scratch2/BMC/rcm1/rhs/fv3/regional/processed/surf_oper_rrfs_r131_v1/08_test/

# %% [markdown]
# ### Open Obs
#
# Now for monet-analysis we will open preprocessed data in either netcdf icartt or some other format.  We will not be retrieving data like monetio does for some observations (ie aeronet, airnow, etc....).  Instead we will provide utitilies to do this so that users can add more data easily.
#
# Like models we list all obs objects in the yaml file and it will loop through and create driver.observation instances that include the model type, file, objects (i.e. data object) and label

# %%
an.open_obs()

# %%
#All the info in the observation class can also be called.
an.obs['airnow'].obj
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 2163, x: 3790, y: 1)
# Coordinates:
#   * x           (x) int64 0 1 2 3 4 5 6 7 ... 3783 3784 3785 3786 3787 3788 3789
#   * time        (time) datetime64[ns] 2019-08-01 ... 2019-08-31T00:30:00
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     siteid      (y, x) object ...
# Dimensions without coordinates: y
# Data variables: (12/30)
#     BARPR       (time, y, x) float64 ...
#     BC          (time, y, x) float64 ...
#     CO          (time, y, x) float64 nan nan nan nan nan ... nan nan nan nan nan
#     NO          (time, y, x) float64 nan nan nan nan nan ... nan nan nan nan nan
#     NO2         (time, y, x) float64 nan nan nan nan nan ... nan nan nan nan nan
#     NO2Y        (time, y, x) float64 ...
#     ...          ...
#     cmsa_name   (y, x) float64 ...
#     msa_code    (y, x) float64 ...
#     msa_name    (y, x) object ...
#     state_name  (y, x) object ...
#     epa_region  (y, x) object ...
#     time_local  (time, y, x) datetime64[ns] ...
# Attributes:
#     title:
#     format:        NetCDF-4
#     date_created:  2021-06-07

# %%
#This pairs the data
an.pair_data()
# Out:
# [########################################] | 100% Completed | 14.9s
# [########################################] | 100% Completed | 15.0s
# [########################################] | 100% Completed | 15.1s
# [########################################] | 100% Completed | 15.2s
# [########################################] | 100% Completed |  0.5s
# [########################################] | 100% Completed |  0.6s
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.8s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s

# %%
#And this generates all the plots.
an.plotting()
# Out:
# Warning: ty_scale not specified for CO, so default used.
# Reference std: 280.8085194614225
# Warning: ty_scale not specified for CO, so default used.
# Warning: ty_scale not specified for CO, so default used.
# Warning: ty_scale not specified for NO2, so default used.
# Reference std: 8.282009757088371
# Warning: ty_scale not specified for NO2, so default used.
# Warning: ty_scale not specified for NO2, so default used.
# Warning: ty_scale not specified for NO, so default used.
# Reference std: 10.7437811451812
# Warning: ty_scale not specified for NO, so default used.
# Warning: ty_scale not specified for NO, so default used.
# Reference std: 8.16234098325183
# Warning: ty_scale not specified for OZONE, so default used.
# Reference std: 17.374055615507505
# Warning: ty_scale not specified for OZONE, so default used.
# Warning: ty_scale not specified for OZONE, so default used.
# /scratch2/BMC/rcm1/rhs/MONET/monet/monet/plots/mapgen.py:53: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, ax = plt.subplots(figsize=figsize, subplot_kw={"projection": crs})
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.8s
# [########################################] | 100% Completed |  0.9s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  5.6s
# [########################################] | 100% Completed |  5.7s
# [########################################] | 100% Completed |  5.8s
# [########################################] | 100% Completed |  5.9s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  0.5s
# [########################################] | 100% Completed |  0.6s
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.5s
# [########################################] | 100% Completed |  0.6s
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.7s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  3.1s
# [########################################] | 100% Completed |  3.1s
# [########################################] | 100% Completed |  3.2s
# [########################################] | 100% Completed |  3.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.7s
# [########################################] | 100% Completed |  2.8s
# [########################################] | 100% Completed |  2.9s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.4s
# [########################################] | 100% Completed |  2.0s
# [########################################] | 100% Completed |  2.1s
# [########################################] | 100% Completed |  2.2s
# [########################################] | 100% Completed |  2.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s
# [########################################] | 100% Completed |  0.1s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.2s
# [########################################] | 100% Completed |  0.3s

# %%
#This creates the stats. This is quite slow right now.
#You are welcome to test, but it is underdevelopment.
#Don't choose too many stats at once or too long of a 
#period or the code takes a long time to run.
an.stats()
